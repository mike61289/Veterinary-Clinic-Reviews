# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import statsmodels.api as sm
import scipy as sc
from scipy.stats import mode
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import Normalizer,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import gensim
import re
import gensim.downloader as model_api
from sklearn.model_selection import train_test_split

# %%
ahc = pd.read_csv('Animal Health Clinic.csv')
ahc
# Out:
#             Date               Name  \
# 0     3 days ago     Neda S. Abbasi
# 1     6 days ago  Marie-Ève Saucier
# 2     6 days ago       Dan Raileanu
# 3     a week ago    Nathalie Berube
# 4     a week ago  Andrew Schartmann
# ..           ...                ...
# 473  7 years ago              Liv L
# 474  7 years ago     chloe rousseau
# 475  8 years ago  Stephanie Russell
# 476  8 years ago        sandra joan
# 477  9 years ago         Anika Cote
#
#                                                 Review     Rating
# 0    For us The Animal Health Clinic is the most tr...   5 stars
# 1    J'ai pas réussi à me faire servir le trio File...   5 stars
# 2                                                  NaN   5 stars
# 3    Ma Bella a reçu les meilleurs soins a cette cl...   5 stars
# 4    AVOID THIS PLACE AT ALL COSTS. Seriously. They...    1 star
# ..                                                 ...        ...
# 473  I have been this clinic 4-5 times and with all...   2 stars
# ...

# %%
ahc = ahc.dropna()
ahc = ahc.drop(['Date', 'Name'], axis = 1)

# %%
ahc.Rating = ahc.Rating.str.replace('5 stars', '5')
ahc.Rating = ahc.Rating.str.replace('4 stars', '4')
ahc.Rating = ahc.Rating.str.replace('3 stars', '3')
ahc.Rating = ahc.Rating.str.replace('2 stars', '2')
ahc.Rating = ahc.Rating.str.replace('1 star', '1')
ahc.Rating = ahc.Rating.astype(int)
ahc
# Out:
#                                                 Review  Rating
# 0    For us The Animal Health Clinic is the most tr...       5
# 1    J'ai pas réussi à me faire servir le trio File...       5
# 3    Ma Bella a reçu les meilleurs soins a cette cl...       5
# 4    AVOID THIS PLACE AT ALL COSTS. Seriously. They...       1
# 5    God bless these people. Every single staff mem...       5
# ..                                                 ...     ...
# 472  They ran the extra mile to save my cat who was...       5
# 473  I have been this clinic 4-5 times and with all...       2
# 474  i had an amazing experience . the vet that hel...       5
# 475  I took my 8 year old cat to the Animal Health ...       5
# 476  i absolutely love this place,u can tell they r...       5
#
# [263 rows x 2 columns]

# %%
ahc.Review = ahc.Review.astype(str)
ahc.Review = [x.lower() for x in ahc.Review]

# %%
words = ahc.Review.str.split()
words = pd.DataFrame(words.tolist())

# %%
replaceDict = dict({
'{':" ", '}':" ", ',':"", '.':" ", '!':" ", '\\':" ", '/':" ", '$':" ", '%':" ",
'^':" ", '?':" ", '\'':" ", '"':" ", '(':" ", ')':" ", '*':" ", '+':" ", '-':" ",
'=':" ", ':':" ", ';':" ", ']':" ", '[':" ", '`':" ", '~':" ",
})

rep = dict((re.escape(k), v) for k, v in replaceDict.items())
pattern = re.compile("|".join(rep.keys()))

def replacer(text):
    return rep[re.escape(text.group(0))]

words = ahc.Review.str.replace(pattern, replacer).str.lower().str.split()
words = pd.DataFrame(words.tolist())
words
# Out:
#         0           1      2        3           4          5          6   \
# 0      for          us    the   animal      health     clinic         is
# 1        j          ai    pas   réussi           à         me      faire
# 2       ma       bella      a     reçu         les  meilleurs      soins
# 3    avoid        this  place       at         all      costs  seriously
# 4      god       bless  these   people       every     single      staff
# ..     ...         ...    ...      ...         ...        ...        ...
# 258   they         ran    the    extra        mile         to       save
# 259      i        have   been     this      clinic          4          5
# 260      i         had     an  amazing  experience        the        vet
# 261      i        took     my        8        year        old        cat
# 262      i  absolutely   love     this      placeu        can       tell
#
#          7             8            9   ...    57    58    59    60    61  \
# ...

# %%
word_vectors = model_api.load("glove-wiki-gigaword-200")

words.columns = words.columns.astype(str)

def soft_get(w):
    try:
        return word_vectors[w]
    except KeyError:
        return np.zeros(word_vectors.vector_size)
    
def map_vectors(row):
    try:
        return np.sum(
            row.loc[row.notna()].apply(soft_get)
        )
    except:
        return np.zeros(word_vectors.vector_size)
    
emb = pd.DataFrame(words.apply(map_vectors, axis=1))
emb.columns = ['C']
emb = pd.DataFrame(np.array(emb.C.apply(pd.Series)))
emb
# Out:
#            0          1         2          3         4          5    \
# 0    12.981274  11.451395  6.121834  -5.379018 -1.548679  -1.194835
# 1     9.157775   4.189547 -2.582699   4.746149  8.324012 -15.481245
# 2     5.901135   0.917838 -2.597969  -2.717525  3.357732 -13.659573
# 3     2.003942   3.470788 -2.863652 -10.206798  0.882532  -1.389963
# 4     2.189287   8.126793  1.736074  -3.113890 -3.628306  -1.110940
# ..         ...        ...       ...        ...       ...        ...
# 258   3.300324   3.638532 -3.950961  -8.540932 -2.423173   1.645673
# 259   4.834779  13.342199 -4.436426 -10.462494 -5.774205  -0.328229
# 260  10.414967   5.650099 -5.031567 -15.646539 -0.584010   1.386153
# 261   2.517422   6.830019 -6.175427  -9.246857 -0.968192   1.770890
# 262   9.780111   7.454750  1.159098  -9.808879  3.554847  -3.262330
#
#            6         7         8          9    ...        190       191  \
# 0   -21.177921  0.204504  1.538508  16.611724  ...  -6.566648  2.532629
# ...

# %%
emb = emb.fillna(0)

# %%
X = Normalizer().fit_transform(emb) #Normalizer gives better score
sgdr = SGDRegressor()
sgdr.fit(X, ahc['Rating'])
ahc['gensim'] = sgdr.predict(X)
sgdr.score(X, ahc['Rating']) #not very good
# Out:
# 0.06800826536566784

# %%
COMPRESSED_SIZE = 200

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(ahc['Review'])

Xd = X.toarray()
Xd = PCA(COMPRESSED_SIZE).fit(Xd.T).components_.T
Xd = sm.add_constant(Xd)

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(emb)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show() #3 clusters is the way to go

# %%
k = 3
model = KMeans(n_clusters = k, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
clusters = model.predict(X)

# %%
y = np.array(ahc['Rating'])
labels = np.zeros_like(clusters)
for i in range(5):
    mask = (clusters == i)
    labels[clusters == i] = mode(y[clusters == i])[0]

# %%
ahc['kmeans_tfidf'] = labels
ahc
# Out:
#                                                 Review  Rating    gensim  \
# 0    for us the animal health clinic is the most tr...       5  4.421662
# 1    j'ai pas réussi à me faire servir le trio file...       5  3.490368
# 3    ma bella a reçu les meilleurs soins a cette cl...       5  3.589989
# 4    avoid this place at all costs. seriously. they...       1  4.111136
# 5    god bless these people. every single staff mem...       5  4.344921
# ..                                                 ...     ...       ...
# 472  they ran the extra mile to save my cat who was...       5  4.332849
# 473  i have been this clinic 4-5 times and with all...       2  4.240050
# 474  i had an amazing experience . the vet that hel...       5  4.248590
# 475  i took my 8 year old cat to the animal health ...       5  4.325651
# 476  i absolutely love this place,u can tell they r...       5  4.343516
#
#      kmeans_tfidf
# 0               5
# 1               5
# 3               5
# ...

# %%
fowlkes_mallows_score(ahc.kmeans_tfidf, y) #best results for this clinic
# Out:
# 0.7508738704898305

# %%
accuracy_score(ahc.kmeans_tfidf, y)
# Out:
# 0.7376425855513308

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test))) #best
# Out:
# Accuracy of logistic regression classifier on test set: 0.71

# %%
fowlkes_mallows_score(y_pred, y_test)
# Out:
# 0.7235546427186239
