# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import statsmodels.api as sm
from scipy.stats import mode
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import Normalizer
import gensim
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import re
import gensim.downloader as model_api

# %%
hvoe = pd.read_csv('hvoe.csv')
hvoe
# Out:
#             Date                  Name  \
# 0     3 days ago          TheTabletguy
# 1     a week ago  Jason Poirier Lavoie
# 2     a week ago   Carlos Ceja cazares
# 3    2 weeks ago         mara voltaire
# 4    3 weeks ago             Samme Lem
# ..           ...                   ...
# 342  6 years ago      Danielle Poitras
# 343  6 years ago                Vy Van
# 344  6 years ago                h. muh
# 345  7 years ago               Jootchy
# 346  8 years ago     Paulitien Beaudon
#
#                                                 Review     Rating
# 0                                                  NaN   5 stars
# 1                                                  NaN   5 stars
# 2    Best care your family pet will get. The whole ...   5 stars
# 3    A very nice, clean place. Employées very polit...   5 stars
# 4    (Translated by Google) This is the second time...    1 star
# ..                                                 ...        ...
# ...

# %%
hvoe = hvoe.dropna()
hvoe = hvoe.drop(['Date', 'Name'], axis = 1)

# %%
hvoe.Rating = hvoe.Rating.str.replace('5 stars', '5')
hvoe.Rating = hvoe.Rating.str.replace('4 stars', '4')
hvoe.Rating = hvoe.Rating.str.replace('3 stars', '3')
hvoe.Rating = hvoe.Rating.str.replace('2 stars', '2')
hvoe.Rating = hvoe.Rating.str.replace('1 star', '1')
hvoe.Rating = hvoe.Rating.astype(int)
hvoe
# Out:
#                                                 Review  Rating
# 2    Best care your family pet will get. The whole ...       5
# 3    A very nice, clean place. Employées very polit...       5
# 4    (Translated by Google) This is the second time...       1
# 5    Thanks so much, receptionist was very pleasant...       5
# 6    (Translated by Google) She took the time to ca...       4
# ..                                                 ...     ...
# 342  (Translated by Google) I am a client of this c...       5
# 343  (Translated by Google) Veterinary Center laval...       1
# 344  My sister took my bird there yesterday since h...       1
# 345  Friendly staff and a veterinarian who know how...       5
# 346  From my experience they are recommendable and ...       2
#
# [215 rows x 2 columns]

# %%
hvoe.Review = hvoe.Review.astype(str)
hvoe.Review = [x.lower() for x in hvoe.Review]

# %%
words = hvoe.Review.str.split()
words = pd.DataFrame(words.tolist())

# %%
replaceDict = dict({
'{':" ", '}':" ", ',':"", '.':" ", '!':" ", '\\':" ", '/':" ", '$':" ", '%':" ",
'^':" ", '?':" ", '\'':" ", '"':" ", '(':" ", ')':" ", '*':" ", '+':" ", '-':" ",
'=':" ", ':':" ", ';':" ", ']':" ", '[':" ", '`':" ", '~':" ",
})

rep = dict((re.escape(k), v) for k, v in replaceDict.items())
pattern = re.compile("|".join(rep.keys()))

def replacer(text):
    return rep[re.escape(text.group(0))]

words = hvoe.Review.str.replace(pattern, replacer).str.lower().str.split()
words = pd.DataFrame(words.tolist())
words
# Out:
#              0       1           2             3             4   \
# 0          best    care        your        family           pet
# 1             a    very        nice         clean         place
# 2    translated      by      google          this            is
# 3        thanks      so        much  receptionist           was
# 4    translated      by      google           she          took
# ..          ...     ...         ...           ...           ...
# 210  translated      by      google             i            am
# 211  translated      by      google    veterinary        center
# 212          my  sister        took            my          bird
# 213    friendly   staff         and             a  veterinarian
# 214        from      my  experience          they           are
#
#                 5          6          7      8        9   ...    45    46  \
# 0             will        get        the  whole    staff  ...  None  None
# ...

# %%
word_vectors = model_api.load("word2vec-google-news-300")

words.columns = words.columns.astype(str)

def soft_get(w):
    try:
        return word_vectors[w]
    except KeyError:
        return np.zeros(word_vectors.vector_size)
    
def map_vectors(row):
    try:
        return np.sum(
            row.loc[row.notna()].apply(soft_get)
        )
    except:
        return np.zeros(word_vectors.vector_size)
    
emb = pd.DataFrame(words.apply(map_vectors, axis=1))
emb.columns = ['C']
emb = pd.DataFrame(np.array(emb.C.apply(pd.Series)))
emb
# Out:
#           0         1         2         3         4         5         6    \
# 0    0.195221  1.550331  1.163696  4.137482 -1.558563  0.690166  2.068115
# 1   -0.377197  1.196045  0.384277  0.519043 -1.483398 -0.396729  0.007446
# 2    0.140961  1.465162  1.018555  5.309143 -4.150345  0.415260  0.986725
# 3    0.004898 -0.027161 -0.416473  0.755939 -0.428101  0.681519  0.725220
# 4   -0.177551  1.340759  0.922546  1.267822 -0.175934  0.322388  0.149414
# ..        ...       ...       ...       ...       ...       ...       ...
# 210 -0.301483  0.965759 -0.781441  3.084961 -1.247730  0.288879  0.783775
# 211 -0.680023 -0.047913  0.849625  3.447357 -0.369915 -0.667847  0.214905
# 212 -0.064240  2.870667  0.598694  1.338423 -2.045288 -0.471062 -0.820232
# 213  1.187775  0.921438  0.690613  2.298096 -2.826859  0.603691  2.348267
# 214  2.028229  0.581809  0.259155  3.719036 -4.183228  1.100708  3.243317
#
#           7         8         9    ...       290       291       292  \
# ...

# %%
emb = emb.fillna(0)

# %%
X = Normalizer().fit_transform(emb) #Normalizer gives better score
sgdr = SGDRegressor()
sgdr.fit(X, hvoe['Rating'])
hvoe['gensim'] = sgdr.predict(X)
sgdr.score(X, hvoe['Rating']) #not very good
# Out:
# 0.2716612176655442

# %%
COMPRESSED_SIZE = 200

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(hvoe['Review'])

Xd = X.toarray()
Xd = PCA(COMPRESSED_SIZE).fit(Xd.T).components_.T
Xd = sm.add_constant(Xd)

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(emb)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show() #3 clusters is the way to go

# %%
k = 3
model = KMeans(n_clusters = k, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
clusters = model.predict(X)

# %%
y = np.array(hvoe['Rating'])
labels = np.zeros_like(clusters)
for i in range(5):
    mask = (clusters == i)
    labels[clusters == i] = mode(y[clusters == i])[0]

# %%
hvoe['kmeans_tfidf'] = labels
hvoe
# Out:
#                                                 Review  Rating    gensim  \
# 2    best care your family pet will get. the whole ...       5  4.745394
# 3    a very nice, clean place. employées very polit...       5  4.869269
# 4    (translated by google) this is the second time...       1  4.005755
# 5    thanks so much, receptionist was very pleasant...       5  4.609003
# 6    (translated by google) she took the time to ca...       4  4.215462
# ..                                                 ...     ...       ...
# 342  (translated by google) i am a client of this c...       5  4.085435
# 343  (translated by google) veterinary center laval...       1  3.872061
# 344  my sister took my bird there yesterday since h...       1  3.425475
# 345  friendly staff and a veterinarian who know how...       5  4.027859
# 346  from my experience they are recommendable and ...       2  4.037126
#
#      kmeans_tfidf
# 2               5
# 3               5
# 4               5
# ...

# %%
fowlkes_mallows_score(hvoe.kmeans_tfidf, y)
# Out:
# 0.7953898900269853

# %%
accuracy_score(hvoe.kmeans_tfidf, y)
# Out:
# 0.786046511627907

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.82

# %%
fowlkes_mallows_score(y_pred, y_test) #best results
# Out:
# 0.8212911973041175
