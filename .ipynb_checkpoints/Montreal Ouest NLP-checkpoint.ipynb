# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import statsmodels.api as sm
import scipy as sc
from scipy.stats import mode
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import Normalizer,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import gensim
import re
import gensim.downloader as model_api
from sklearn.model_selection import train_test_split

# %%
mo = pd.read_csv('Montreal Ouest.csv')
mo
# Out:
#             Date                  Name  \
# 0    2 weeks ago  Christyn Greczkowski
# 1    a month ago    Christian Fritschi
# 2    a month ago   Carlos Ceja cazares
# 3    a month ago        Cindy Ibberson
# 4   2 months ago        Richard Fuller
# ..           ...                   ...
# 63   4 years ago          Kent Conover
# 64   4 years ago       Annie Perreault
# 65   4 years ago          Matthew Ward
# 66   4 years ago     Serge Bouharevich
# 67   5 years ago           Mila Araujo
#
#                                                Review     Rating
# 0                                                 NaN   5 stars
# 1                                                 NaN   5 stars
# 2   Excellent service, all recommendations and tre...   5 stars
# 3   Dr Bernier has the experience, expertise and k...   5 stars
# 4   We had to bring our dog into the UK which was ...   5 stars
# ..                                                ...        ...
# ...

# %%
mo = mo.dropna()
mo = mo.drop(['Date', 'Name'], axis = 1)

# %%
mo.Rating = mo.Rating.str.replace('5 stars', '5')
mo.Rating = mo.Rating.str.replace('4 stars', '4')
mo.Rating = mo.Rating.str.replace('3 stars', '3')
mo.Rating = mo.Rating.str.replace('2 stars', '2')
mo.Rating = mo.Rating.str.replace('1 star', '1')
mo.Rating = mo.Rating.astype(int)
mo
# Out:
#                                                Review  Rating
# 2   Excellent service, all recommendations and tre...       5
# 3   Dr Bernier has the experience, expertise and k...       5
# 4   We had to bring our dog into the UK which was ...       5
# 6   Nothing to say against Dr Bernier but his rece...       1
# 7   Dr. Bernier is an excellent vet. Gives great a...       5
# 11  (Translated by Google) Very nice welcome, and ...       5
# 12                                        Not comment       1
# 13  (Translated by Google) Professional service de...       5
# 15                        Friendly and knowledgeable!       5
# 16  I didn’t receive a good service and the staff ...       2
# 18  Dr Yves Bernier is a delight to communicate wi...       5
# 25  Dr. Yves Bernier has been our veterinarian sin...       5
# 26  Best Veterinary establishment I've ever been t...       5
# 29  Though Dr Bernier seems like a caring vet, thi...       2
# ...

# %%
mo.Review = mo.Review.astype(str)
mo.Review = [x.lower() for x in mo.Review]

# %%
words = mo.Review.str.split()
words = pd.DataFrame(words.tolist())

# %%
replaceDict = dict({
'{':" ", '}':" ", ',':"", '.':" ", '!':" ", '\\':" ", '/':" ", '$':" ", '%':" ",
'^':" ", '?':" ", '\'':" ", '"':" ", '(':" ", ')':" ", '*':" ", '+':" ", '-':" ",
'=':" ", ':':" ", ';':" ", ']':" ", '[':" ", '`':" ", '~':" ",
})

rep = dict((re.escape(k), v) for k, v in replaceDict.items())
pattern = re.compile("|".join(rep.keys()))
def replacer(text):
    return rep[re.escape(text.group(0))]

words = mo.Review.str.replace(pattern, replacer).str.lower().str.split()
words = pd.DataFrame(words.tolist())
words
# Out:
#             0             1              2                3             4   \
# 0    excellent       service            all  recommendations           and
# 1           dr       bernier            has              the    experience
# 2           we           had             to            bring           our
# 3      nothing            to            say          against            dr
# 4           dr       bernier             is               an     excellent
# 5   translated            by         google             very          nice
# 6          not       comment           None             None          None
# 7   translated            by         google     professional       service
# 8     friendly           and  knowledgeable             None          None
# 9            i        didn’t        receive                a          good
# 10          dr          yves        bernier               is             a
# ...

# %%
word_vectors = model_api.load("glove-wiki-gigaword-200")

words.columns = words.columns.astype(str)

def soft_get(w):
    try:
        return word_vectors[w]
    except KeyError:
        return np.zeros(word_vectors.vector_size)
    
def map_vectors(row):
    try:
        return np.sum(
            row.loc[row.notna()].apply(soft_get)
        )
    except:
        return np.zeros(word_vectors.vector_size)
    
emb = pd.DataFrame(words.apply(map_vectors, axis=1))
emb.columns = ['C']
emb = pd.DataFrame(np.array(emb.C.apply(pd.Series)))
emb
# Out:
#           0          1         2         3         4         5          6    \
# 0    3.790835   5.628105 -0.214386 -2.379318  2.242207 -1.603343 -10.671869
# 1    1.829961   0.943281  2.551716 -2.048176  0.551626  0.002471  -3.198712
# 2    5.732659   9.071368 -3.317924 -7.672544 -2.103755  4.899065 -20.006998
# 3    3.215300   2.890969 -0.268295 -3.648567  2.101283  0.729112  -6.227817
# 4    2.639240   0.608667  2.892867 -0.627529  3.065216 -1.397601  -1.484908
# 5    7.744104   5.782642 -0.616591 -4.969574  4.906366 -7.547556 -11.478476
# 6    0.946940   1.066440  0.458023 -0.994560  0.193640  0.937680  -1.762380
# 7    8.117480   8.284109  2.741063 -3.392649  4.322887 -0.140407 -14.862656
# 8    1.236220   0.555040  1.209817 -0.089074  0.304418 -0.433807  -0.944164
# 9    2.970211   1.957062  1.918713 -3.926954 -2.153623 -1.255096  -4.196818
# 10  11.978178  11.661292  1.067387 -7.284353  3.024160  3.040536 -20.742298
# ...

# %%
emb = emb.fillna(0)

# %%
X = Normalizer().fit_transform(emb) #Normalizer gives better score
sgdr = SGDRegressor()
sgdr.fit(X, mo['Rating'])
mo['gensim'] = sgdr.predict(X)
sgdr.score(X, mo['Rating']) #not very good
# Out:
# 0.05286040732185926

# %%
COMPRESSED_SIZE = 30

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(mo['Review'])

Xd = X.toarray()
Xd = PCA(COMPRESSED_SIZE).fit(Xd.T).components_.T
Xd = sm.add_constant(Xd)

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(emb)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show() #3 clusters is the way to go

# %%
k = 3
model = KMeans(n_clusters = k, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
clusters = model.predict(X)

# %%
y = np.array(mo['Rating'])
labels = np.zeros_like(clusters)
for i in range(5):
    mask = (clusters == i)
    labels[clusters == i] = mode(y[clusters == i])[0]

# %%
mo['kmeans_tfidf'] = labels
mo
# Out:
#                                                Review  Rating    gensim  \
# 2   excellent service, all recommendations and tre...       5  4.415688
# 3   dr bernier has the experience, expertise and k...       5  4.417998
# 4   we had to bring our dog into the uk which was ...       5  4.425138
# 6   nothing to say against dr bernier but his rece...       1  4.364675
# 7   dr. bernier is an excellent vet. gives great a...       5  4.349166
# 11  (translated by google) very nice welcome, and ...       5  4.215466
# 12                                        not comment       1  3.782057
# 13  (translated by google) professional service de...       5  4.408976
# 15                        friendly and knowledgeable!       5  4.055772
# 16  i didn’t receive a good service and the staff ...       2  4.380581
# 18  dr yves bernier is a delight to communicate wi...       5  4.442687
# 25  dr. yves bernier has been our veterinarian sin...       5  4.438532
# ...

# %%
fowlkes_mallows_score(mo.kmeans_tfidf, y)
# Out:
# 0.8082629978148029

# %%
accuracy_score(mo.kmeans_tfidf, y) #best results for this clinic
# Out:
# 0.8064516129032258

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.70

# %%
fowlkes_mallows_score(y_pred, y_test)
# Out:
# 0.699205898780101
