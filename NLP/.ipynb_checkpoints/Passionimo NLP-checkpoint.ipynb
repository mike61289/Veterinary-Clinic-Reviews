# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import statsmodels.api as sm
import scipy as sc
from scipy.stats import mode
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import Normalizer,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import gensim
import re
import gensim.downloader as model_api
from sklearn.model_selection import train_test_split
# Out:
# /Users/Coding/mambaforge/lib/python3.9/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
passionimo = pd.read_csv('/Users/Coding/Desktop/School/Final Project/Data/Passionimo.csv')
passionimo
# Out:
#             Date               Name  \
# 0     6 days ago        Maude R. V.
# 1     a week ago      amanda faigal
# 2    4 weeks ago       Sophie A. D.
# 3    a month ago     Yvonne Gardner
# 4    a month ago    nancy boudrault
# ..           ...                ...
# 260  4 years ago   Suzie Brouillard
# 261  4 years ago         Atef Sdiri
# 262  4 years ago   Daniel Montpetit
# 263  4 years ago  Michelle Franklin
# 264  6 years ago       DIego CAstro
#
#                                                 Review     Rating
# 0                                                  NaN   5 stars
# 1    I've been a few times now for my guineapigs an...   5 stars
# 2    (Translated by Google) I would like to thank t...   5 stars
# 3               Great service. Friendly helpful staff.   5 stars
# 4    (Translated by Google) Very professional servi...   5 stars
# ..                                                 ...        ...
# 260  (Translated by Google) I am rather sad. I like...   3 stars
# ...

# %%
passionimo = passionimo.dropna()
passionimo = passionimo.drop(['Date', 'Name'], axis = 1)

# %%
passionimo.Rating = passionimo.Rating.str.replace('5 stars', '5')
passionimo.Rating = passionimo.Rating.str.replace('4 stars', '4')
passionimo.Rating = passionimo.Rating.str.replace('3 stars', '3')
passionimo.Rating = passionimo.Rating.str.replace('2 stars', '2')
passionimo.Rating = passionimo.Rating.str.replace('1 star', '1')
passionimo.Rating = passionimo.Rating.astype(int)
passionimo
# Out:
#                                                 Review  Rating
# 1    I've been a few times now for my guineapigs an...       5
# 2    (Translated by Google) I would like to thank t...       5
# 3               Great service. Friendly helpful staff.       5
# 4    (Translated by Google) Very professional servi...       5
# 5    The friendliest staff you'll ever meet who ask...       5
# ..                                                 ...     ...
# 258  Thank you for the financial rape.....you lure ...       1
# 259  (Translated by Google) WOW! MY favorite clinic...       5
# 260  (Translated by Google) I am rather sad. I like...       3
# 262  (Translated by Google) Great team of veterinar...       5
# 263  Excellent service. We've taken all our pets to...       5
#
# [181 rows x 2 columns]

# %%
passionimo.Review = passionimo.Review.astype(str)
passionimo.Review = [x.lower() for x in passionimo.Review]

# %%
words = passionimo.Review.str.split()
words = pd.DataFrame(words.tolist())

# %%
replaceDict = dict({
'{':" ", '}':" ", ',':"", '.':" ", '!':" ", '\\':" ", '/':" ", '$':" ", '%':" ",
'^':" ", '?':" ", '\'':" ", '"':" ", '(':" ", ')':" ", '*':" ", '+':" ", '-':" ",
'=':" ", ':':" ", ';':" ", ']':" ", '[':" ", '`':" ", '~':" ",
})

rep = dict((re.escape(k), v) for k, v in replaceDict.items())
pattern = re.compile("|".join(rep.keys()))

def replacer(text):
    return rep[re.escape(text.group(0))]

words = passionimo.Review.str.replace(pattern, replacer).str.lower().str.split()
words = pd.DataFrame(words.tolist())
words
# Out:
#              0            1         2        3             4         5   \
# 0             i           ve      been        a           few     times
# 1    translated           by    google        i         would      like
# 2         great      service  friendly  helpful         staff      None
# 3    translated           by    google     very  professional   service
# 4           the  friendliest     staff      you            ll      ever
# ..          ...          ...       ...      ...           ...       ...
# 176       thank          you       for      the     financial      rape
# 177  translated           by    google      wow            my  favorite
# 178  translated           by    google        i            am    rather
# 179  translated           by    google    great          team        of
# 180   excellent      service        we       ve         taken       all
#
#                 6      7            8           9   ...           48    49  \
# ...

# %%
word_vectors = model_api.load("glove-wiki-gigaword-200")

words.columns = words.columns.astype(str)

def soft_get(w):
    try:
        return word_vectors[w]
    except KeyError:
        return np.zeros(word_vectors.vector_size)
    
def map_vectors(row):
    try:
        return np.sum(
            row.loc[row.notna()].apply(soft_get)
        )
    except:
        return np.zeros(word_vectors.vector_size)
    
emb = pd.DataFrame(words.apply(map_vectors, axis=1))
emb.columns = ['C']
emb = pd.DataFrame(np.array(emb.C.apply(pd.Series)))
emb
# Out:
#            0          1         2          3         4         5          6    \
# 0     5.831113  10.957036 -3.064618  -4.904972 -7.120308  0.131489 -20.938167
# 1     4.295800   4.538602  1.625791  -5.309518 -0.805488  0.837738 -14.912613
# 2     2.761840   0.591320  2.014230  -0.088393  0.999753 -1.688791  -1.660604
# 3     7.488974   2.345225  0.435675   0.581299  4.028471 -8.242161  -8.457589
# 4     9.229345   8.311447 -0.711027  -5.896833 -0.631000  3.207880 -16.946087
# ..         ...        ...       ...        ...       ...       ...        ...
# 176  10.385386   4.463491 -3.387605  -6.063736 -2.836434  0.906281 -16.184465
# 177   4.698089   7.766754 -2.780425  -4.689255 -0.331477 -2.883318 -13.387660
# 178   3.224962   6.609595  1.752022 -10.898308 -2.111708 -2.233537 -17.316208
# 179   1.938662   6.263182  0.897403   1.295480  5.086283 -5.006626  -6.045719
# 180   6.735659  11.484977 -6.325294  -6.835496 -0.871701 -4.908537 -15.426423
#
# ...

# %%
emb = emb.fillna(0)

# %%
X = Normalizer().fit_transform(emb) #Normalizer gives better score
sgdr = SGDRegressor()
sgdr.fit(X, passionimo['Rating'])
passionimo['gensim'] = sgdr.predict(X)
sgdr.score(X, passionimo['Rating']) #not very good
# Out:
# 0.013397322675622103

# %%
COMPRESSED_SIZE = 150

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(passionimo['Review'])

Xd = X.toarray()
Xd = PCA(COMPRESSED_SIZE).fit(Xd.T).components_.T
Xd = sm.add_constant(Xd)

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(emb)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show() #3 clusters is the way to go

# %%
k = 3
model = KMeans(n_clusters = k, init = 'k-means++', max_iter = 100, n_init = 1)
model.fit(X)
clusters = model.predict(X)

# %%
y = np.array(passionimo['Rating'])
labels = np.zeros_like(clusters)
for i in range(5):
    mask = (clusters == i)
    labels[clusters == i] = mode(y[clusters == i])[0]

# %%
passionimo['kmeans_tfidf'] = labels
passionimo
# Out:
#                                                 Review  Rating    gensim  \
# 1    i've been a few times now for my guineapigs an...       5  4.674097
# 2    (translated by google) i would like to thank t...       5  4.726466
# 3               great service. friendly helpful staff.       5  4.537205
# 4    (translated by google) very professional servi...       5  4.741676
# 5    the friendliest staff you'll ever meet who ask...       5  4.641185
# ..                                                 ...     ...       ...
# 258  thank you for the financial rape.....you lure ...       1  4.642552
# 259  (translated by google) wow! my favorite clinic...       5  4.728093
# 260  (translated by google) i am rather sad. i like...       3  4.717955
# 262  (translated by google) great team of veterinar...       5  4.758096
# 263  excellent service. we've taken all our pets to...       5  4.688059
#
#      kmeans_tfidf
# 1               5
# 2               5
# 3               5
# ...

# %%
fowlkes_mallows_score(passionimo.kmeans_tfidf, y) #best results for this clinic
# Out:
# 0.9022174442775687

# %%
accuracy_score(passionimo.kmeans_tfidf, y)
# Out:
# 0.9005524861878453

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.89

# %%
fowlkes_mallows_score(y_pred, y_test)
# Out:
# 0.8921656774162499
